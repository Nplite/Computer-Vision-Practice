# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/001_SUNNY_BHAVEEN_CHANDRA/001_My_Classes/FSDS_Feb_Batch/ALL_NOTES/April-30-ObjectDetectionSetup
# Out:
# /content/drive/MyDrive/001_SUNNY_BHAVEEN_CHANDRA/001_My_Classes/FSDS_Feb_Batch/ALL_NOTES/April-30-ObjectDetectionSetup

# %%
# !pwd
# Out:
# /content/drive/MyDrive/001_SUNNY_BHAVEEN_CHANDRA/001_My_Classes/FSDS_Feb_Batch/ALL_NOTES/April-30-ObjectDetectionSetup

# %%
# %%writefile requirements.txt
# tensorflow==2.7.0
# tf-models-official
# tensorflow_io==0.23.1
# notebook
# Cython
# # git+https://github.com/philferriere/cocoapi.git#subdirectory=PythonAPI
# Out:
# Writing requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 489.6 MB 23 kB/s
# ...
#      |████████████████████████████████| 2.2 MB 50.6 MB/s
# ...
#      |████████████████████████████████| 23.1 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 463 kB 58.3 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 76.0 MB/s
# ...
#      |████████████████████████████████| 2.1 MB 55.7 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 90 kB 12.1 MB/s
# ...
#      |████████████████████████████████| 99 kB 13.8 MB/s
# ...
#      |████████████████████████████████| 237 kB 59.5 MB/s
# ...
#      |████████████████████████████████| 47.8 MB 1.6 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 58.0 MB/s
# ...
#      |████████████████████████████████| 352 kB 79.0 MB/s
# ...
#      |████████████████████████████████| 1.8 MB 80.6 MB/s
# ...
#      |████████████████████████████████| 596 kB 92.9 MB/s
# ...
#      |████████████████████████████████| 4.9 MB 61.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 64.7 MB/s
# ...

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !mkdir TensorFlow

# %%
# !mv models TensorFlow
# %cd TensorFlow

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 72396, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 72396 (delta 1), reused 8 (delta 1), pack-reused 72384
# Receiving objects: 100% (72396/72396), 579.06 MiB | 15.74 MiB/s, done.
# Resolving deltas: 100% (51203/51203), done.
# Checking out files: 100% (3037/3037), done.

# %%
# !protoc --version # already installed in colab
# Out:
# libprotoc 3.0.0

# %%
# %cd TensorFlow/models/research
# Out:
# /content/drive/MyDrive/001_SUNNY_BHAVEEN_CHANDRA/001_My_Classes/FSDS_Feb_Batch/ALL_NOTES/April-30-ObjectDetectionSetup/TensorFlow/models/research

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# !pip install git+https://github.com/philferriere/cocoapi.git#subdirectory=PythonAPI
# Out:
# ...
#   Cloning https://github.com/philferriere/cocoapi.git to /tmp/pip-req-build-gx988kuz
#   Running command git clone -q https://github.com/philferriere/cocoapi.git /tmp/pip-req-build-gx988kuz
# ...
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp37-cp37m-linux_x86_64.whl size=264438 sha256=8d6a8c277bed2fe6397c794b666846735052db6a96ba0aa19a3c10771ca76868
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9l9dhjoh/wheels/6b/c6/c5/cb6da4cb793a6cb1ab91f6578d76c42686422127eb4dbcea94
# Successfully built pycocotools
# ...
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.4
#     Uninstalling pycocotools-2.0.4:
#       Successfully uninstalled pycocotools-2.0.4
# ...

# %%
# !pwd
# Out:
# /content/drive/MyDrive/001_SUNNY_BHAVEEN_CHANDRA/001_My_Classes/FSDS_Feb_Batch/ALL_NOTES/April-30-ObjectDetectionSetup/TensorFlow/models/research

# %%
# !cp object_detection/packages/tf2/setup.py .

# %%
# !python -m pip install .
# Out:
# Processing /content/drive/MyDrive/001_SUNNY_BHAVEEN_CHANDRA/001_My_Classes/FSDS_Feb_Batch/ALL_NOTES/April-30-ObjectDetectionSetup/TensorFlow/models/research
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#      |████████████████████████████████| 10.2 MB 15.8 MB/s
# ...
#      |████████████████████████████████| 253 kB 65.9 MB/s
# ...
#      |████████████████████████████████| 46 kB 4.5 MB/s
# ...
#      |████████████████████████████████| 508 kB 60.3 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.2 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 49.7 MB/s
# ...
#      |████████████████████████████████| 151 kB 67.2 MB/s
# ...

# %%
# !python object_detection/builders/model_builder_tf2_test.py
# Out:
# Running tests under Python 3.7.13: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2022-04-30 11:28:41.471112: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# W0430 11:28:41.690938 140412668290944 model_builder.py:1102] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.47s
# I0430 11:28:42.032208 140412668290944 test_util.py:2309] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.47s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.49s
# ...

# %%
# !pwd
# Out:
# /content/drive/MyDrive/001_SUNNY_BHAVEEN_CHANDRA/001_My_Classes/FSDS_Feb_Batch/ALL_NOTES/April-30-ObjectDetectionSetup

# %%
# !python plot_object_detection_simple.py
# Out:
# ...
# Traceback (most recent call last):
#   File "plot_object_detection_simple.py", line 115, in <module>
#     from object_detection.utils import label_map_util
# ModuleNotFoundError: No module named 'object_detection'
